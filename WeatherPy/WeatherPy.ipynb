# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Generate Cities List---------------------------------------------------

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 594

# %%
#Lists and counters
city_list = []
cloud_list = []
country_list = []
date_list = []
humidity_list = []
lats_list = []
lngs_list = []
temp_max_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %%
#Perform API Calls-------------------------------------------

# %%
print("Beginning Data Retrieval ")
print("-------------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

#For loop matching city names with city_list using enumerate method
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_list.append(response["name"])
        cloud_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lats_list.append(response["coord"]["lat"])
        lngs_list.append(response["coord"]["lon"])
        temp_max_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        
        else:
            index_counter = index_counter + 1
        
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}")
        
    except(KeyError, IndexError):
        print("City not found. Skipping...")
        
print("-------------------------------")
print("Data Retrieval Complete")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 : at-bashi
# Processing Record 2 of Set 1 : busselton
# Processing Record 3 of Set 1 : mar del plata
# Processing Record 4 of Set 1 : punta arenas
# Processing Record 5 of Set 1 : provideniya
# Processing Record 6 of Set 1 : moron
# Processing Record 7 of Set 1 : yulara
# Processing Record 8 of Set 1 : rikitea
# Processing Record 9 of Set 1 : tuktoyaktuk
# Processing Record 10 of Set 1 : albany
# Processing Record 11 of Set 1 : ilhabela
# Processing Record 12 of Set 1 : kaitangata
# Processing Record 13 of Set 1 : mataura
# Processing Record 14 of Set 1 : klaksvik
# City not found. Skipping...
# Processing Record 15 of Set 1 : mbuji-mayi
# Processing Record 16 of Set 1 : evensk
# Processing Record 17 of Set 1 : hermanus
# City not found. Skipping...
# Processing Record 18 of Set 1 : new norfolk
# Processing Record 19 of Set 1 : clyde river
# Processing Record 20 of Set 1 : half moon bay
# Processing Record 21 of Set 1 : talnakh
# City not found. Skipping...
# Processing Record 22 of Set 1 : butaritari
# Processing Record 23 of Set 1 : ahipara
# Processing Record 24 of Set 1 : rawson
# Processing Record 25 of Set 1 : nouadhibou
# Processing Record 26 of Set 1 : palmer
# Processing Record 27 of Set 1 : kodiak
# Processing Record 28 of Set 1 : ushuaia
# Processing Record 29 of Set 1 : kasongo-lunda
# Processing Record 30 of Set 1 : vaini
# Processing Record 31 of Set 1 : bengkulu
# Processing Record 32 of Set 1 : arman
# Processing Record 33 of Set 1 : pevek
# Processing Record 34 of Set 1 : nabire
# Processing Record 35 of Set 1 : thompson
# Processing Record 36 of Set 1 : port elizabeth
# Processing Record 37 of Set 1 : cabo san lucas
# Processing Record 38 of Set 1 : zalantun
# Processing Record 39 of Set 1 : znamenskoye
# Processing Record 40 of Set 1 : arraial do cabo
# Processing Record 41 of Set 1 : timbiras
# Processing Record 42 of Set 1 : chuy
# Processing Record 43 of Set 1 : roald
# Processing Record 44 of Set 1 : escanaba
# Processing Record 45 of Set 1 : murmashi
# Processing Record 46 of Set 1 : grandview
# Processing Record 47 of Set 1 : santa isabel do rio negro
# Processing Record 48 of Set 1 : cabedelo
# Processing Record 49 of Set 1 : ahtopol
# Processing Record 50 of Set 1 : merrill
# Processing Record 0 of Set 2 : mantua
# Processing Record 1 of Set 2 : kudahuvadhoo
# Processing Record 2 of Set 2 : kirakira
# Processing Record 3 of Set 2 : ribeira grande
# Processing Record 4 of Set 2 : tasiilaq
# Processing Record 5 of Set 2 : coquimbo
# Processing Record 6 of Set 2 : katsuura
# Processing Record 7 of Set 2 : port alfred
# Processing Record 8 of Set 2 : nanortalik
# Processing Record 9 of Set 2 : puerto ayora
# Processing Record 10 of Set 2 : port blair
# Processing Record 11 of Set 2 : axim
# Processing Record 12 of Set 2 : riyadh
# Processing Record 13 of Set 2 : hithadhoo
# Processing Record 14 of Set 2 : sola
# City not found. Skipping...
# Processing Record 15 of Set 2 : camopi
# Processing Record 16 of Set 2 : arkhangelsk
# Processing Record 17 of Set 2 : honningsvag
# Processing Record 18 of Set 2 : kysyl-syr
# Processing Record 19 of Set 2 : ostrovnoy
# Processing Record 20 of Set 2 : kilindoni
# Processing Record 21 of Set 2 : bredasdorp
# Processing Record 22 of Set 2 : kapaa
# Processing Record 23 of Set 2 : la ronge
# City not found. Skipping...
# Processing Record 24 of Set 2 : umm kaddadah
# Processing Record 25 of Set 2 : athabasca
# Processing Record 26 of Set 2 : ponta do sol
# Processing Record 27 of Set 2 : barrow
# Processing Record 28 of Set 2 : qaanaaq
# Processing Record 29 of Set 2 : kavieng
# Processing Record 30 of Set 2 : mahebourg
# Processing Record 31 of Set 2 : faanui
# Processing Record 32 of Set 2 : lamu
# Processing Record 33 of Set 2 : matara
# City not found. Skipping...
# Processing Record 34 of Set 2 : aykhal
# Processing Record 35 of Set 2 : severo-kurilsk
# Processing Record 36 of Set 2 : artyom
# Processing Record 37 of Set 2 : bathsheba
# Processing Record 38 of Set 2 : bluff
# Processing Record 39 of Set 2 : novyy urengoy
# Processing Record 40 of Set 2 : guisa
# Processing Record 41 of Set 2 : souillac
# Processing Record 42 of Set 2 : bridlington
# Processing Record 43 of Set 2 : christchurch
# Processing Record 44 of Set 2 : atuona
# Processing Record 45 of Set 2 : hobart
# Processing Record 46 of Set 2 : trairi
# Processing Record 47 of Set 2 : vila franca do campo
# City not found. Skipping...
# Processing Record 48 of Set 2 : charters towers
# Processing Record 49 of Set 2 : dikson
# Processing Record 50 of Set 2 : waingapu
# Processing Record 0 of Set 3 : brae
# Processing Record 1 of Set 3 : fort nelson
# Processing Record 2 of Set 3 : vung tau
# Processing Record 3 of Set 3 : luderitz
# Processing Record 4 of Set 3 : doha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 3 : sitka
# City not found. Skipping...
# Processing Record 6 of Set 3 : pamanukan
# City not found. Skipping...
# Processing Record 7 of Set 3 : saint-joseph
# Processing Record 8 of Set 3 : avarua
# Processing Record 9 of Set 3 : amuntai
# Processing Record 10 of Set 3 : buala
# Processing Record 11 of Set 3 : partenit
# Processing Record 12 of Set 3 : padang
# Processing Record 13 of Set 3 : port hardy
# Processing Record 14 of Set 3 : nikolskoye
# Processing Record 15 of Set 3 : polovinnoye
# Processing Record 16 of Set 3 : tutoia
# Processing Record 17 of Set 3 : yellowknife
# Processing Record 18 of Set 3 : cam ranh
# City not found. Skipping...
# Processing Record 19 of Set 3 : karlskrona
# Processing Record 20 of Set 3 : shelburne
# Processing Record 21 of Set 3 : saskylakh
# Processing Record 22 of Set 3 : alofi
# Processing Record 23 of Set 3 : jamestown
# Processing Record 24 of Set 3 : mitsamiouli
# Processing Record 25 of Set 3 : kazanskaya
# Processing Record 26 of Set 3 : avera
# Processing Record 27 of Set 3 : rovaniemi
# Processing Record 28 of Set 3 : mecca
# Processing Record 29 of Set 3 : roma
# Processing Record 30 of Set 3 : tessalit
# Processing Record 31 of Set 3 : georgetown
# Processing Record 32 of Set 3 : torbay
# Processing Record 33 of Set 3 : gushikawa
# Processing Record 34 of Set 3 : kikwit
# Processing Record 35 of Set 3 : nagyatad
# Processing Record 36 of Set 3 : okhotsk
# Processing Record 37 of Set 3 : zhezkazgan
# City not found. Skipping...
# Processing Record 38 of Set 3 : aleksandrov gay
# Processing Record 39 of Set 3 : hirara
# Processing Record 40 of Set 3 : long xuyen
# Processing Record 41 of Set 3 : tecoanapa
# Processing Record 42 of Set 3 : houma
# Processing Record 43 of Set 3 : ancud
# Processing Record 44 of Set 3 : narrabri
# Processing Record 45 of Set 3 : halifax
# Processing Record 46 of Set 3 : coolum beach
# Processing Record 47 of Set 3 : kavaratti
# Processing Record 48 of Set 3 : manggar
# Processing Record 49 of Set 3 : akhmeta
# Processing Record 50 of Set 3 : mulege
# Processing Record 0 of Set 4 : touros
# Processing Record 1 of Set 4 : bowen
# Processing Record 2 of Set 4 : cape town
# Processing Record 3 of Set 4 : rahuri
# Processing Record 4 of Set 4 : bingol
# Processing Record 5 of Set 4 : bubaque
# Processing Record 6 of Set 4 : castro
# Processing Record 7 of Set 4 : tezu
# Processing Record 8 of Set 4 : namatanai
# City not found. Skipping...
# Processing Record 9 of Set 4 : alasehir
# Processing Record 10 of Set 4 : pangkalanbuun
# Processing Record 11 of Set 4 : andros town
# Processing Record 12 of Set 4 : peniche
# Processing Record 13 of Set 4 : staryy nadym
# Processing Record 14 of Set 4 : xining
# Processing Record 15 of Set 4 : ouargaye
# Processing Record 16 of Set 4 : hambantota
# Processing Record 17 of Set 4 : tommot
# Processing Record 18 of Set 4 : paso de los toros
# City not found. Skipping...
# Processing Record 19 of Set 4 : tashla
# Processing Record 20 of Set 4 : hasaki
# Processing Record 21 of Set 4 : sorong
# Processing Record 22 of Set 4 : requena
# Processing Record 23 of Set 4 : geraldton
# Processing Record 24 of Set 4 : paita
# Processing Record 25 of Set 4 : bandarbeyla
# City not found. Skipping...
# Processing Record 26 of Set 4 : buribay
# Processing Record 27 of Set 4 : zhaoqing
# Processing Record 28 of Set 4 : xushan
# City not found. Skipping...
# Processing Record 29 of Set 4 : shimanovsk
# Processing Record 30 of Set 4 : bumba
# City not found. Skipping...
# Processing Record 31 of Set 4 : srandakan
# Processing Record 32 of Set 4 : ugoofaaru
# Processing Record 33 of Set 4 : ostersund
# Processing Record 34 of Set 4 : gigmoto
# Processing Record 35 of Set 4 : muros
# City not found. Skipping...
# Processing Record 36 of Set 4 : hilo
# Processing Record 37 of Set 4 : san quintin
# Processing Record 38 of Set 4 : puga
# Processing Record 39 of Set 4 : esperance
# Processing Record 40 of Set 4 : khatanga
# Processing Record 41 of Set 4 : caravelas
# Processing Record 42 of Set 4 : constitucion
# City not found. Skipping...
# Processing Record 43 of Set 4 : victoria
# Processing Record 44 of Set 4 : phan thiet
# Processing Record 45 of Set 4 : east london
# Processing Record 46 of Set 4 : zaysan
# Processing Record 47 of Set 4 : diffa
# Processing Record 48 of Set 4 : clarence town
# Processing Record 49 of Set 4 : natubleng
# Processing Record 50 of Set 4 : bambous virieux
# City not found. Skipping...
# Processing Record 0 of Set 5 : tocopilla
# Processing Record 1 of Set 5 : tuatapere
# Processing Record 2 of Set 5 : kambove
# Processing Record 3 of Set 5 : hovd
# Processing Record 4 of Set 5 : targusor
# Processing Record 5 of Set 5 : wagar
# City not found. Skipping...
# Processing Record 6 of Set 5 : bermejo
# Processing Record 7 of Set 5 : lanigan
# City not found. Skipping...
# Processing Record 8 of Set 5 : sungaipenuh
# Processing Record 9 of Set 5 : tual
# Processing Record 10 of Set 5 : palana
# Processing Record 11 of Set 5 : byron bay
# Processing Record 12 of Set 5 : hamilton
# Processing Record 13 of Set 5 : ayr
# City not found. Skipping...
# Processing Record 14 of Set 5 : lebu
# Processing Record 15 of Set 5 : krutinka
# Processing Record 16 of Set 5 : garowe
# City not found. Skipping...
# Processing Record 17 of Set 5 : springfield
# Processing Record 18 of Set 5 : dunedin
# Processing Record 19 of Set 5 : uvinza
# Processing Record 20 of Set 5 : kruisfontein
# Processing Record 21 of Set 5 : cidreira
# Processing Record 22 of Set 5 : kutum
# Processing Record 23 of Set 5 : synya
# City not found. Skipping...
# Processing Record 24 of Set 5 : panji
# Processing Record 25 of Set 5 : vardo
# City not found. Skipping...
# Processing Record 26 of Set 5 : dakar
# Processing Record 27 of Set 5 : sao francisco
# Processing Record 28 of Set 5 : hue
# Processing Record 29 of Set 5 : gobabis
# Processing Record 30 of Set 5 : ozernovskiy
# Processing Record 31 of Set 5 : mweka
# Processing Record 32 of Set 5 : veraval
# City not found. Skipping...
# Processing Record 33 of Set 5 : izhma
# Processing Record 34 of Set 5 : tornio
# Processing Record 35 of Set 5 : tshikapa
# Processing Record 36 of Set 5 : mehamn
# Processing Record 37 of Set 5 : tromso
# Processing Record 38 of Set 5 : portland
# Processing Record 39 of Set 5 : matagami
# Processing Record 40 of Set 5 : upernavik
# Processing Record 41 of Set 5 : timra
# Processing Record 42 of Set 5 : suluq
# Processing Record 43 of Set 5 : sinnamary
# Processing Record 44 of Set 5 : elko
# Processing Record 45 of Set 5 : snezhnogorsk
# Processing Record 46 of Set 5 : niceville
# Processing Record 47 of Set 5 : poum
# Processing Record 48 of Set 5 : pochutla
# Processing Record 49 of Set 5 : hauterive
# Processing Record 50 of Set 5 : tabou
# Processing Record 0 of Set 6 : santa maria
# Processing Record 1 of Set 6 : pandan
# Processing Record 2 of Set 6 : zhoucheng
# Processing Record 3 of Set 6 : tahlequah
# Processing Record 4 of Set 6 : kipushi
# City not found. Skipping...
# Processing Record 5 of Set 6 : sironj
# Processing Record 6 of Set 6 : rundu
# Processing Record 7 of Set 6 : carnarvon
# Processing Record 8 of Set 6 : saint-georges
# Processing Record 9 of Set 6 : lagoa
# Processing Record 10 of Set 6 : havelock
# Processing Record 11 of Set 6 : coari
# Processing Record 12 of Set 6 : esmeraldas
# Processing Record 13 of Set 6 : meadow lake
# Processing Record 14 of Set 6 : lelystad
# Processing Record 15 of Set 6 : son la
# Processing Record 16 of Set 6 : sioux lookout
# Processing Record 17 of Set 6 : hokitika
# Processing Record 18 of Set 6 : rawah
# Processing Record 19 of Set 6 : nautla
# Processing Record 20 of Set 6 : karpathos
# Processing Record 21 of Set 6 : kindu
# City not found. Skipping...
# Processing Record 22 of Set 6 : lavrentiya
# Processing Record 23 of Set 6 : sao filipe
# Processing Record 24 of Set 6 : airai
# Processing Record 25 of Set 6 : ampanihy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 6 : norman wells
# Processing Record 27 of Set 6 : nuuk
# Processing Record 28 of Set 6 : chokurdakh
# Processing Record 29 of Set 6 : saint george
# Processing Record 30 of Set 6 : sladkovo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 6 : emba
# City not found. Skipping...
# Processing Record 32 of Set 6 : grants pass
# Processing Record 33 of Set 6 : pahrump
# Processing Record 34 of Set 6 : lompoc
# City not found. Skipping...
# Processing Record 35 of Set 6 : allanridge
# Processing Record 36 of Set 6 : lazaro cardenas
# Processing Record 37 of Set 6 : luganville
# Processing Record 38 of Set 6 : bati
# Processing Record 39 of Set 6 : mahanoro
# Processing Record 40 of Set 6 : pathein
# Processing Record 41 of Set 6 : marang
# Processing Record 42 of Set 6 : qasigiannguit
# Processing Record 43 of Set 6 : cepu
# Processing Record 44 of Set 6 : tvoroyri
# Processing Record 45 of Set 6 : aloleng
# Processing Record 46 of Set 6 : guerrero negro
# Processing Record 47 of Set 6 : derzhavinsk
# Processing Record 48 of Set 6 : minab
# Processing Record 49 of Set 6 : aranda de duero
# City not found. Skipping...
# Processing Record 50 of Set 6 : san angelo
# Processing Record 0 of Set 7 : ilulissat
# Processing Record 1 of Set 7 : karaton
# Processing Record 2 of Set 7 : pacific grove
# Processing Record 3 of Set 7 : kahului
# Processing Record 4 of Set 7 : henties bay
# Processing Record 5 of Set 7 : porkhov
# Processing Record 6 of Set 7 : iqaluit
# Processing Record 7 of Set 7 : hobyo
# Processing Record 8 of Set 7 : tiksi
# Processing Record 9 of Set 7 : cherskiy
# Processing Record 10 of Set 7 : quatre cocos
# Processing Record 11 of Set 7 : los llanos de aridane
# Processing Record 12 of Set 7 : nome
# Processing Record 13 of Set 7 : navalmoral de la mata
# Processing Record 14 of Set 7 : pecos
# Processing Record 15 of Set 7 : marsh harbour
# Processing Record 16 of Set 7 : yumen
# Processing Record 17 of Set 7 : damietta
# Processing Record 18 of Set 7 : port lincoln
# Processing Record 19 of Set 7 : labuhan
# Processing Record 20 of Set 7 : la asuncion
# Processing Record 21 of Set 7 : manicore
# Processing Record 22 of Set 7 : havre-saint-pierre
# Processing Record 23 of Set 7 : olafsvik
# Processing Record 24 of Set 7 : patos
# City not found. Skipping...
# Processing Record 25 of Set 7 : westport
# Processing Record 26 of Set 7 : tirumullaivasal
# Processing Record 27 of Set 7 : uige
# Processing Record 28 of Set 7 : barra do garcas
# Processing Record 29 of Set 7 : oksfjord
# Processing Record 30 of Set 7 : nantucket
# Processing Record 31 of Set 7 : namibe
# Processing Record 32 of Set 7 : taybad
# Processing Record 33 of Set 7 : mount isa
# Processing Record 34 of Set 7 : bethel
# Processing Record 35 of Set 7 : mao
# Processing Record 36 of Set 7 : prince rupert
# Processing Record 37 of Set 7 : aklavik
# Processing Record 38 of Set 7 : boa vista
# Processing Record 39 of Set 7 : the valley
# Processing Record 40 of Set 7 : bagaces
# Processing Record 41 of Set 7 : margate
# Processing Record 42 of Set 7 : pak phanang
# Processing Record 43 of Set 7 : rochegda
# Processing Record 44 of Set 7 : ocean city
# Processing Record 45 of Set 7 : dukat
# Processing Record 46 of Set 7 : baripada
# Processing Record 47 of Set 7 : finschhafen
# Processing Record 48 of Set 7 : palpa
# Processing Record 49 of Set 7 : artsyz
# City not found. Skipping...
# Processing Record 50 of Set 7 : north bend
# Processing Record 0 of Set 8 : kawalu
# Processing Record 1 of Set 8 : smirnykh
# Processing Record 2 of Set 8 : te anau
# Processing Record 3 of Set 8 : pimentel
# Processing Record 4 of Set 8 : labuan
# Processing Record 5 of Set 8 : pemba
# Processing Record 6 of Set 8 : longyearbyen
# Processing Record 7 of Set 8 : tiznit
# Processing Record 8 of Set 8 : sakakah
# Processing Record 9 of Set 8 : bayonet point
# Processing Record 10 of Set 8 : kieta
# Processing Record 11 of Set 8 : sydney mines
# Processing Record 12 of Set 8 : ixtapa
# Processing Record 13 of Set 8 : san patricio
# Processing Record 14 of Set 8 : benguela
# Processing Record 15 of Set 8 : iracoubo
# Processing Record 16 of Set 8 : zhuhai
# Processing Record 17 of Set 8 : okato
# Processing Record 18 of Set 8 : adrar
# City not found. Skipping...
# Processing Record 19 of Set 8 : mokrousovo
# Processing Record 20 of Set 8 : ushtobe
# Processing Record 21 of Set 8 : lannion
# City not found. Skipping...
# Processing Record 22 of Set 8 : chulman
# Processing Record 23 of Set 8 : ninh binh
# Processing Record 24 of Set 8 : kushima
# City not found. Skipping...
# Processing Record 25 of Set 8 : nyurba
# Processing Record 26 of Set 8 : uzhur
# Processing Record 27 of Set 8 : america dourada
# Processing Record 28 of Set 8 : maceio
# Processing Record 29 of Set 8 : warrington
# City not found. Skipping...
# Processing Record 30 of Set 8 : abu samrah
# Processing Record 31 of Set 8 : nemuro
# Processing Record 32 of Set 8 : coihaique
# Processing Record 33 of Set 8 : saint-pierre
# Processing Record 34 of Set 8 : urumqi
# Processing Record 35 of Set 8 : sainte-luce
# Processing Record 36 of Set 8 : kyra
# Processing Record 37 of Set 8 : tonantins
# Processing Record 38 of Set 8 : rio grande
# Processing Record 39 of Set 8 : ribeira brava
# Processing Record 40 of Set 8 : port augusta
# Processing Record 41 of Set 8 : bafq
# Processing Record 42 of Set 8 : ngunguru
# Processing Record 43 of Set 8 : oranjemund
# Processing Record 44 of Set 8 : kamaishi
# Processing Record 45 of Set 8 : assiniboia
# Processing Record 46 of Set 8 : mosquera
# Processing Record 47 of Set 8 : berbera
# Processing Record 48 of Set 8 : tuhian
# Processing Record 49 of Set 8 : berlevag
# Processing Record 50 of Set 8 : uthal
# Processing Record 0 of Set 9 : camara de lobos
# Processing Record 1 of Set 9 : parsabad
# Processing Record 2 of Set 9 : honiara
# Processing Record 3 of Set 9 : sept-iles
# City not found. Skipping...
# Processing Record 4 of Set 9 : mount gambier
# Processing Record 5 of Set 9 : willow grove
# Processing Record 6 of Set 9 : hervey bay
# Processing Record 7 of Set 9 : leningradskiy
# Processing Record 8 of Set 9 : kailua
# Processing Record 9 of Set 9 : januaria
# Processing Record 10 of Set 9 : kralendijk
# Processing Record 11 of Set 9 : inhambane
# Processing Record 12 of Set 9 : narasaraopet
# Processing Record 13 of Set 9 : miri
# Processing Record 14 of Set 9 : kodinsk
# Processing Record 15 of Set 9 : vanimo
# Processing Record 16 of Set 9 : trincomalee
# Processing Record 17 of Set 9 : kibala
# Processing Record 18 of Set 9 : dong hoi
# Processing Record 19 of Set 9 : husavik
# Processing Record 20 of Set 9 : baykit
# City not found. Skipping...
# Processing Record 21 of Set 9 : teknaf
# Processing Record 22 of Set 9 : bontang
# Processing Record 23 of Set 9 : turukhansk
# Processing Record 24 of Set 9 : mahina
# Processing Record 25 of Set 9 : lidkoping
# Processing Record 26 of Set 9 : aljezur
# Processing Record 27 of Set 9 : samarai
# Processing Record 28 of Set 9 : omsukchan
# Processing Record 29 of Set 9 : broome
# Processing Record 30 of Set 9 : ust-ilimsk
# Processing Record 31 of Set 9 : goderich
# Processing Record 32 of Set 9 : batemans bay
# Processing Record 33 of Set 9 : faya
# City not found. Skipping...
# Processing Record 34 of Set 9 : marsa matruh
# Processing Record 35 of Set 9 : kachug
# Processing Record 36 of Set 9 : rio gallegos
# Processing Record 37 of Set 9 : mocuba
# Processing Record 38 of Set 9 : atasu
# Processing Record 39 of Set 9 : komsomolskiy
# Processing Record 40 of Set 9 : ayotzintepec
# Processing Record 41 of Set 9 : ossora
# Processing Record 42 of Set 9 : saint-philippe
# Processing Record 43 of Set 9 : weligama
# Processing Record 44 of Set 9 : bulgan
# Processing Record 45 of Set 9 : forrest city
# Processing Record 46 of Set 9 : chitral
# Processing Record 47 of Set 9 : grindavik
# Processing Record 48 of Set 9 : kalmunai
# Processing Record 49 of Set 9 : verkhnevilyuysk
# Processing Record 50 of Set 9 : rimbey
# City not found. Skipping...
# Processing Record 0 of Set 10 : fortuna
# City not found. Skipping...
# Processing Record 1 of Set 10 : vezirkopru
# Processing Record 2 of Set 10 : mettur
# Processing Record 3 of Set 10 : narsaq
# Processing Record 4 of Set 10 : vorsma
# Processing Record 5 of Set 10 : linfen
# Processing Record 6 of Set 10 : santa rosa
# Processing Record 7 of Set 10 : oistins
# Processing Record 8 of Set 10 : skjervoy
# Processing Record 9 of Set 10 : solnechnyy
# Processing Record 10 of Set 10 : guane
# Processing Record 11 of Set 10 : thinadhoo
# Processing Record 12 of Set 10 : ust-omchug
# Processing Record 13 of Set 10 : sorland
# Processing Record 14 of Set 10 : batabano
# Processing Record 15 of Set 10 : zhigansk
# Processing Record 16 of Set 10 : vsevolozhsk
# Processing Record 17 of Set 10 : govindgarh
# Processing Record 18 of Set 10 : pundaguitan
# Processing Record 19 of Set 10 : usinsk
# Processing Record 20 of Set 10 : khandyga
# Processing Record 21 of Set 10 : acari
# Processing Record 22 of Set 10 : mollendo
# Processing Record 23 of Set 10 : oda
# Processing Record 24 of Set 10 : cayenne
# Processing Record 25 of Set 10 : vanavara
# Processing Record 26 of Set 10 : kattivakkam
# Processing Record 27 of Set 10 : san lawrenz
# Processing Record 28 of Set 10 : waipawa
# Processing Record 29 of Set 10 : kalabo
# Processing Record 30 of Set 10 : pampa
# Processing Record 31 of Set 10 : shirokiy
# Processing Record 32 of Set 10 : kadnikov
# Processing Record 33 of Set 10 : am timan
# Processing Record 34 of Set 10 : risod
# Processing Record 35 of Set 10 : tucuman
# Processing Record 36 of Set 10 : belmopan
# Processing Record 37 of Set 10 : taminango
# Processing Record 38 of Set 10 : bhatkal
# Processing Record 39 of Set 10 : leh
# City not found. Skipping...
# Processing Record 40 of Set 10 : prabumulih
# Processing Record 41 of Set 10 : arua
# Processing Record 42 of Set 10 : yushan
# Processing Record 43 of Set 10 : harper
# City not found. Skipping...
# Processing Record 44 of Set 10 : aquiraz
# Processing Record 45 of Set 10 : yar-sale
# City not found. Skipping...
# Processing Record 46 of Set 10 : andenes
# Processing Record 47 of Set 10 : tazovskiy
# Processing Record 48 of Set 10 : kasempa
# Processing Record 49 of Set 10 : strezhevoy
# City not found. Skipping...
# Processing Record 50 of Set 10 : gien
# Processing Record 0 of Set 11 : tulsipur
# Processing Record 1 of Set 11 : bayan
# Processing Record 2 of Set 11 : russell
# Processing Record 3 of Set 11 : terrace
# Processing Record 4 of Set 11 : kroya
# Processing Record 5 of Set 11 : cascais
# Processing Record 6 of Set 11 : channel-port aux basques
# Processing Record 7 of Set 11 : blagoyevo
# Processing Record 8 of Set 11 : anito
# Processing Record 9 of Set 11 : nobeoka
# Processing Record 10 of Set 11 : bayanday
# Processing Record 11 of Set 11 : coahuayana
# Processing Record 12 of Set 11 : aryanah
# Processing Record 13 of Set 11 : paranaiba
# Processing Record 14 of Set 11 : dezhou
# Processing Record 15 of Set 11 : sampit
# Processing Record 16 of Set 11 : baoro
# Processing Record 17 of Set 11 : khasan
# Processing Record 18 of Set 11 : morant bay
# Processing Record 19 of Set 11 : raudeberg
# Processing Record 20 of Set 11 : pisco
# Processing Record 21 of Set 11 : lasem
# Processing Record 22 of Set 11 : sumenep
# Processing Record 23 of Set 11 : banda aceh
# City not found. Skipping...
# Processing Record 24 of Set 11 : galle
# Processing Record 25 of Set 11 : oga
# Processing Record 26 of Set 11 : dongning
# Processing Record 27 of Set 11 : svetlogorsk
# Processing Record 28 of Set 11 : malyye derbety
# Processing Record 29 of Set 11 : madang
# Processing Record 30 of Set 11 : saint-francois
# Processing Record 31 of Set 11 : straumen
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
#Convert Raw Data to DataFrame---------------------------------------

# %%
#Create a dataframe using information from data retrieval
weather_data = pd.DataFrame({
    "City" : city_list,
    "Lat" : lats_list,
    "Lng" : lngs_list,
    "Max Temp" : temp_max_list,
    "Humidity" : humidity_list,
    "Clouds" : cloud_list,
    "Wind Speed" : wind_speed_list,
    "Country" : country_list,
    "Date" : date_list    
})

# %%
#Count weather data
weather_data.count()
# Out:
# City          541
# Lat           541
# Lng           541
# Max Temp      541
# Humidity      541
# Clouds        541
# Wind Speed    541
# Country       541
# Date          541
# dtype: int64

# %%
#Display dataframe
weather_data.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Clouds  Wind Speed  \
# 0       At-Bashi  41.17   75.81     57.88        36       0        2.28
# 1      Busselton -33.65  115.33     52.00        64       0       11.68
# 2  Mar del Plata -38.00  -57.56     54.00        93       0        9.17
# 3   Punta Arenas -53.15  -70.92     35.60        93      92       14.99
# 4    Provideniya  64.38 -173.30     59.49        40      13        6.38
#
#   Country        Date
# 0      KG  1592617018
# 1      AU  1592616867
# 2      AR  1592616878
# 3      CL  1592616876
# 4      RU  1592616873

# %%
#Save weather data to a cities csv file
weather_data.to_csv("output_data/cities.csv", index=False)

# %%
#Plotting the Data------------------------------------------------

# %%
# Latitude vs. Temperature Plot-----------------------------------

# %%
#Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Max Temperature (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %%
#Latitude vs. Humidity Plot----------------------------------------

# %%
#Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Humidity"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Humidity (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%))")
plt.grid(True)
plt.savefig("../Images/City Latitude vs Humidity.png")

# %%
# Latitude vs. Cloudiness Plot----------------------------------

# %%
#Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Clouds"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Cloudiness (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%))")
plt.grid(True)
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %%
# Latitude vs. Wind Speed Plot------------------------------------

# %%
#Latitude vs. Wind Speed Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Wind Speed (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%))")
plt.grid(True)
plt.savefig("../Images/City Latitude vs Wind Speed.png")
